# %% [markdown]
# Assignment 4
# Joshua Dow
# CS150
# Fall 2021

# %%
x=[54,3,7,67,4,34,20,10,72,48]
y=[1,2,3]

# %% [markdown]
# append allows the user to append an element to a list.

# %%
x.append(5)
x
# Out:
# [54, 3, 7, 67, 4, 34, 20, 10, 72, 48, 5]

# %% [markdown]
# extend allows the user to add multiple elements to a list

# %%
x.extend(y)
x
# Out:
# [54, 3, 7, 67, 4, 34, 20, 10, 72, 48, 5, 1, 2, 3]

# %% [markdown]
# insert allows the user to insert an element in a list

# %%
x.insert(3,2)
x
# Out:
# [54, 3, 7, 2, 67, 4, 34, 20, 10, 72, 48, 5, 1, 2, 3]

# %% [markdown]
# remove allows the user to remove elements from a list

# %%
x.remove(20)
x
# Out:
# [54, 3, 7, 2, 67, 4, 34, 10, 72, 48, 5, 1, 2, 3]

# %% [markdown]
# count allows the user to count how many times a particular element appears in a list

# %%
x.count(2)
# Out:
# 2

# %% [markdown]
# index allows the user to see the position of a particular element in a list

# %%
x.index(67)
# Out:
# 4

# %% [markdown]
# pop allows the user to remove a particular position in a list

# %%
x.pop(8)
x
# Out:
# [54, 3, 7, 2, 67, 4, 34, 10, 48, 5, 1, 2, 3]

# %% [markdown]
# sort allows the user to sort a list

# %%
x.sort()
x
# Out:
# [1, 2, 2, 3, 3, 4, 5, 7, 10, 34, 48, 54, 67]

# %% [markdown]
# copy allows the user to copy a list

# %%
x1=x.copy()
x1
# Out:
# [1, 2, 2, 3, 3, 4, 5, 7, 10, 34, 48, 54, 67]

# %%
clear allows the user to totally clear a list

# %%
x1.clear()
x1
# Out:
# []

# %% [markdown]
# any will satisfy a condition if any of the criterea are met

# %%
list=[True,False,True]
x=any(list)
x
# Out:
# True

# %% [markdown]
# filter allows the user to filter certain data from lists

# %%
list1=[43,12,57,3,12,4,6,5,23,2]
def func(x):
    for x in list1:
        if x>10:
            return True
        else:
            return False
list2=filter(func,list1)
for x in list2:
    print(x)
# Out:
# 43
# 12
# 57
# 3
# 12
# 4
# 6
# 5
# 23
# 2

# %% [markdown]
# len allows the user to count how many elements exist in a list

# %%
List = ["one", "two", "three"]
x = len(List)
x
# Out:
# 3

# %% [markdown]
# max allows the user to see the highest value in the list

# %%
max(list1)
# Out:
# 57
